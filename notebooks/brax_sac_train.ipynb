# %% [markdown]
# # Training using SAC in Brax

# %%
#@title Install Brax and some helper modules
#@markdown ## ⚠️ PLEASE NOTE:
#@markdown This colab runs best using a TPU runtime.  From the Colab menu, choose Runtime > Change Runtime Type, then select **'TPU'** in the dropdown.

from datetime import datetime
import functools
import os
from os import getcwd
from os.path import join
from IPython.display import HTML, clear_output

import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt

try:
  import brax
except ImportError:
  # !pip install git+https://github.com/google/brax.git@main
  clear_output()
  import brax

from brax import envs
from brax import jumpy as jp
from brax.io import html
from brax.io import model
from brax.training.agents.ppo import train as ppo
from brax.training.agents.sac import train as sac

if 'COLAB_TPU_ADDR' in os.environ:
  from jax.tools import colab_tpu
  colab_tpu.setup_tpu()

# %% [markdown]
# #### Environment

# %%
env_name = "grasp"
env = envs.get_environment(env_name=env_name)
state = env.reset(rng=jp.random_prngkey(seed=0))

HTML(html.render(env.sys, [state.qp]))
# Out:
# <html>
#   <head>
#     <title>brax visualizer</title>
#     <style>
#       body {
#         margin: 0;
#         padding: 0;
#       }
#       #brax-viewer {
#         margin: 0;
#         padding: 0;
#         height: 480px;
#       }
#     </style>
#   </head>
#   <body>
#     <script type="application/javascript">
#     var system = {"config": {"bodies": [{"name": "torso", "colliders": [{"capsule": {"radius": 0.05, "length": 0.5, "end": 0}, "material": {"friction": 0.9486833, "elasticity": 0.0}, "color": "", "hidden": false, "noContact": false}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "mass": 3.6651914, "frozen": {"position": {"y": 1.0, "x": 0.0, "z": 0.0}, "rotation": {"x": 1.0, "z": 1.0, "y": 0.0}, "all": false}}, {"name": "thigh", "colliders": [{"position": {"z": -0.225, "x": 0.0, "y": 0.0}, "rotation": {"x": 0.0, "y": 0.0, "z": 0.0}, "capsule": {"radius": 0.05, "length": 0.55, "end": 0}, "material": {"friction": 0.9486833, "elasticity": 0.0}, "color": "", "hidden": false, "noContact": false}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "mass": 4.0578904, "frozen": {"position": {"y": 1.0, "x": 0.0, "z": 0.0}, "rotation": {"x": 1.0, "z": 1.0, "y": 0.0}, "all": false}}, {"name": "leg", "colliders": [{"position": {"x": 0.0, "y": 0.0, "z": 0.0}, "rotation": {"x": 0.0, "y": 0.0, "z": 0.0}, "capsule": {"radius": 0.04, "length": 0.58, "end": 0}, "material": {"friction": 0.9486833, "elasticity": 0.0}, "color": "", "hidden": false, "noContact": false}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "mass": 2.7813568, "frozen": {"position": {"y": 1.0, "x": 0.0, "z": 0.0}, "rotation": {"x": 1.0, "z": 1.0, "y": 0.0}, "all": false}}, {"name": "foot", "colliders": [{"position": {"x": -0.065, "y": -0.13, "z": -0.03}, "rotation": {"y": 90.0, "x": 0.0, "z": 0.0}, "capsule": {"radius": 0.06, "length": 0.51, "end": 0}, "material": {"friction": 0.9486833, "elasticity": 0.0}, "color": "", "hidden": false, "noContact": false}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "mass": 5.3155746, "frozen": {"position": {"y": 1.0, "x": 0.0, "z": 0.0}, "rotation": {"x": 1.0, "z": 1.0, "y": 0.0}, "all": false}}, {"name": "floor", "colliders": [{"plane": {}, "material": {"friction": 0.9486833, "elasticity": 0.0}, "color": "", "hidden": false, "noContact": false}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "frozen": {"position": {"x": 1.0, "y": 1.0, "z": 1.0}, "rotation": {"x": 1.0, "y": 1.0, "z": 1.0}, "all": true}, "mass": 0.0}], "joints": [{"name": "thigh_joint", "parent": "torso", "child": "thigh", "parentOffset": {"z": -0.2, "x": 0.0, "y": 0.0}, "rotation": {"z": -90.0, "x": 0.0, "y": 0.0}, "angleLimit": [{"min": -150.0, "max": 0.0}], "stiffness": 0.0, "angularDamping": 0.0}, {"name": "leg_joint", "parent": "thigh", "child": "leg", "parentOffset": {"z": -0.45, "x": 0.0, "y": 0.0}, "childOffset": {"z": 0.25, "x": 0.0, "y": 0.0}, "rotation": {"z": -90.0, "x": 0.0, "y": 0.0}, "angleLimit": [{"min": -150.0, "max": 0.0}], "stiffness": 0.0, "angularDamping": 0.0}, {"name": "foot_joint", "parent": "leg", "child": "foot", "parentOffset": {"z": -0.25, "x": 0.0, "y": 0.0}, "childOffset": {"x": -0.13, "y": -0.13, "z": -0.03}, "rotation": {"z": -90.0, "x": 0.0, "y": 0.0}, "angleLimit": [{"min": -45.0, "max": 45.0}], "stiffness": 0.0, "angularDamping": 0.0}], "actuators": [{"name": "thigh_joint", "joint": "thigh_joint", "strength": 200.0, "torque": {}}, {"name": "leg_joint", "joint": "leg_joint", "strength": 200.0, "torque": {}}, {"name": "foot_joint", "joint": "foot_joint", "strength": 200.0, "torque": {}}], "friction": 0.9486833, "gravity": {"z": -9.81, "x": 0.0, "y": 0.0}, "velocityDamping": 1.0, "angularDamping": -0.05, "collideInclude": [{"first": "floor", "second": "torso"}, {"first": "floor", "second": "thigh"}, {"first": "floor", "second": "leg"}, {"first": "floor", "second": "foot"}], "dt": 0.008, "substeps": 4, "frozen": {"position": {"y": 1.0, "x": 0.0, "z": 0.0}, "rotation": {"x": 1.0, "z": 1.0, "y": 0.0}, "all": false}, "defaults": [{"angles": [{"name": "thigh_joint", "angle": {"x": 0.0, "y": 0.0, "z": 0.0}}, {"name": "leg_joint", "angle": {"x": 0.0, "y": 0.0, "z": 0.0}}], "qps": [{"name": "torso", "pos": {"z": 1.25, "x": 0.0, "y": 0.0}}]}], "dynamicsMode": "pbd", "solverScaleCollide": 1.0, "forces": [], "elasticity": 0.0, "baumgarteErp": 0.0, "colliderCutoff": 0 ...
#     </script>
#     <div id="brax-viewer"></div>
#     <script type="module">
#       import {Viewer} from 'https://cdn.jsdelivr.net/gh/google/brax@v0.1.0/js/viewer.js';
#       const domElement = document.getElementById('brax-viewer');
#       var viewer = new Viewer(domElement, system);
#     </script>
#   </body>
# </html>

# %% [markdown]
# # Training
#
# Brax provides out of the box the following training algorithms:
#
# * [Soft actor-critic](https://github.com/google/brax/blob/main/brax/training/agents/sac/train.py)
#
# Trainers take as input an environment function and some hyperparameters, and return an inference function to operate the environment.

# %%
train_fn = functools.partial(ppo.train, num_timesteps=600_000_000, num_evals=10, reward_scaling=10, episode_length=1000, normalize_observations=True, action_repeat=1, unroll_length=20, num_minibatches=32, num_updates_per_batch=2, discounting=0.99, learning_rate=3e-4, entropy_cost=0.001, num_envs=2048, batch_size=256)

max_y = 100
min_y = 0

xdata, ydata = [], []
times = [datetime.now()]

def progress(num_steps, metrics):
  times.append(datetime.now())
  xdata.append(num_steps)
  ydata.append(metrics['eval/episode_reward'])
  clear_output(wait=True)
  plt.xlim([0, train_fn.keywords['num_timesteps']])
  plt.ylim([min_y, max_y])
  plt.xlabel('# environment steps')
  plt.ylabel('reward per episode')
  plt.plot(xdata, ydata)
  plt.show()

make_inference_fn, params, _ = train_fn(environment=env, progress_fn=progress)

print(f'time to jit: {times[1] - times[0]}')
print(f'time to train: {times[-1] - times[1]}')
# Out:
# time to jit: 0:00:48.129624
# time to train: 0:18:01.294779

# %% [markdown]
# #### Saving and Loading Policies

# %%
output_model_path = join(getcwd(), "sac_params")
model.save_params(output_model_path, params)
params = model.load_params(output_model_path)
inference_fn = make_inference_fn(params)

# %% [markdown]
# ### Visualizing a Policy's Behavior

# %%
env = envs.create(env_name=env_name)
jit_env_reset = jax.jit(env.reset)
jit_env_step = jax.jit(env.step)
jit_inference_fn = jax.jit(inference_fn)

rollout = []
rng = jax.random.PRNGKey(seed=0)
state = jit_env_reset(rng=rng)
for _ in range(1000):
  rollout.append(state)
  act_rng, rng = jax.random.split(rng)
  act, _ = jit_inference_fn(state.obs, act_rng)
  state = jit_env_step(state, act)

HTML(html.render(env.sys, [s.qp for s in rollout]))
# Out:
# <html>
#   <head>
#     <title>brax visualizer</title>
#     <style>
#       body {
#         margin: 0;
#         padding: 0;
#       }
#       #brax-viewer {
#         margin: 0;
#         padding: 0;
#         height: 480px;
#       }
#     </style>
#   </head>
#   <body>
#     <script type="application/javascript">
#     var system = {"config": {"bodies": [{"name": "torso", "colliders": [{"capsule": {"radius": 0.05, "length": 0.5, "end": 0}, "material": {"friction": 0.9486833, "elasticity": 0.0}, "color": "", "hidden": false, "noContact": false}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "mass": 3.6651914, "frozen": {"position": {"y": 1.0, "x": 0.0, "z": 0.0}, "rotation": {"x": 1.0, "z": 1.0, "y": 0.0}, "all": false}}, {"name": "thigh", "colliders": [{"position": {"z": -0.225, "x": 0.0, "y": 0.0}, "rotation": {"x": 0.0, "y": 0.0, "z": 0.0}, "capsule": {"radius": 0.05, "length": 0.55, "end": 0}, "material": {"friction": 0.9486833, "elasticity": 0.0}, "color": "", "hidden": false, "noContact": false}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "mass": 4.0578904, "frozen": {"position": {"y": 1.0, "x": 0.0, "z": 0.0}, "rotation": {"x": 1.0, "z": 1.0, "y": 0.0}, "all": false}}, {"name": "leg", "colliders": [{"position": {"x": 0.0, "y": 0.0, "z": 0.0}, "rotation": {"x": 0.0, "y": 0.0, "z": 0.0}, "capsule": {"radius": 0.04, "length": 0.58, "end": 0}, "material": {"friction": 0.9486833, "elasticity": 0.0}, "color": "", "hidden": false, "noContact": false}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "mass": 2.7813568, "frozen": {"position": {"y": 1.0, "x": 0.0, "z": 0.0}, "rotation": {"x": 1.0, "z": 1.0, "y": 0.0}, "all": false}}, {"name": "foot", "colliders": [{"position": {"x": -0.065, "y": -0.13, "z": -0.03}, "rotation": {"y": 90.0, "x": 0.0, "z": 0.0}, "capsule": {"radius": 0.06, "length": 0.51, "end": 0}, "material": {"friction": 0.9486833, "elasticity": 0.0}, "color": "", "hidden": false, "noContact": false}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "mass": 5.3155746, "frozen": {"position": {"y": 1.0, "x": 0.0, "z": 0.0}, "rotation": {"x": 1.0, "z": 1.0, "y": 0.0}, "all": false}}, {"name": "floor", "colliders": [{"plane": {}, "material": {"friction": 0.9486833, "elasticity": 0.0}, "color": "", "hidden": false, "noContact": false}], "inertia": {"x": 1.0, "y": 1.0, "z": 1.0}, "frozen": {"position": {"x": 1.0, "y": 1.0, "z": 1.0}, "rotation": {"x": 1.0, "y": 1.0, "z": 1.0}, "all": true}, "mass": 0.0}], "joints": [{"name": "thigh_joint", "parent": "torso", "child": "thigh", "parentOffset": {"z": -0.2, "x": 0.0, "y": 0.0}, "rotation": {"z": -90.0, "x": 0.0, "y": 0.0}, "angleLimit": [{"min": -150.0, "max": 0.0}], "stiffness": 0.0, "angularDamping": 0.0}, {"name": "leg_joint", "parent": "thigh", "child": "leg", "parentOffset": {"z": -0.45, "x": 0.0, "y": 0.0}, "childOffset": {"z": 0.25, "x": 0.0, "y": 0.0}, "rotation": {"z": -90.0, "x": 0.0, "y": 0.0}, "angleLimit": [{"min": -150.0, "max": 0.0}], "stiffness": 0.0, "angularDamping": 0.0}, {"name": "foot_joint", "parent": "leg", "child": "foot", "parentOffset": {"z": -0.25, "x": 0.0, "y": 0.0}, "childOffset": {"x": -0.13, "y": -0.13, "z": -0.03}, "rotation": {"z": -90.0, "x": 0.0, "y": 0.0}, "angleLimit": [{"min": -45.0, "max": 45.0}], "stiffness": 0.0, "angularDamping": 0.0}], "actuators": [{"name": "thigh_joint", "joint": "thigh_joint", "strength": 200.0, "torque": {}}, {"name": "leg_joint", "joint": "leg_joint", "strength": 200.0, "torque": {}}, {"name": "foot_joint", "joint": "foot_joint", "strength": 200.0, "torque": {}}], "friction": 0.9486833, "gravity": {"z": -9.81, "x": 0.0, "y": 0.0}, "velocityDamping": 1.0, "angularDamping": -0.05, "collideInclude": [{"first": "floor", "second": "torso"}, {"first": "floor", "second": "thigh"}, {"first": "floor", "second": "leg"}, {"first": "floor", "second": "foot"}], "dt": 0.008, "substeps": 4, "frozen": {"position": {"y": 1.0, "x": 0.0, "z": 0.0}, "rotation": {"x": 1.0, "z": 1.0, "y": 0.0}, "all": false}, "defaults": [{"angles": [{"name": "thigh_joint", "angle": {"x": 0.0, "y": 0.0, "z": 0.0}}, {"name": "leg_joint", "angle": {"x": 0.0, "y": 0.0, "z": 0.0}}], "qps": [{"name": "torso", "pos": {"z": 1.25, "x": 0.0, "y": 0.0}}]}], "dynamicsMode": "pbd", "solverScaleCollide": 1.0, "forces": [], "elasticity": 0.0, "baumgarteErp": 0.0, "colliderCutoff": 0 ...
